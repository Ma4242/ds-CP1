# %%
# !pip install scikit-learn --user --upgrade
# Out:
# ...
#   Using cached numpy-1.23.4-cp38-cp38-win_amd64.whl (14.7 MB)
# ...
#   WARNING: The script f2py.exe is installed in 'C:\Users\hyeon\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# !pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
# ...

# %%
# !pip install pillow
# Out:
# ...
#   Using cached Pillow-9.3.0-cp38-cp38-win_amd64.whl (2.5 MB)
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.6.2-cp38-cp38-win_amd64.whl (7.2 MB)
# ...
#   Using cached fonttools-4.38.0-py3-none-any.whl (965 kB)
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#   Using cached kiwisolver-1.4.4-cp38-cp38-win_amd64.whl (55 kB)
# ...
#   Using cached contourpy-1.0.6-cp38-cp38-win_amd64.whl (163 kB)
# ...

# %%
#https://studying-modory.tistory.com/entry/210305-%EB%94%A5%EB%9F%AC%EB%8B%9D-%EB%8F%99%EB%AC%BC-%EC%9D%B4%EB%AF%B8%EC%A7%80-%EC%9D%B8%EC%8B%9D-%ED%8C%A8%EC%85%98-%EC%9D%B4%EB%AF%B8%EC%A7%80-%EB%B6%84%EB%A5%98
#https://lsjsj92.tistory.com/387
#https://twinw.tistory.com/252
#https://github.com/lsjsj92/keras_basic/blob/master/7.%20predict_multi_img_with_CNN.ipynb

# %%
import os, re, glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
dir = 'D:\\download\\koreanfood\\kfood\\all'
categories = ['가지볶음','간장게장','갈비구이','갈비찜','갈비탕','갈치구이','갈치조림','감자조림',
              '감자채볶음','감자탕','갓김치','건새우볶음','경단','계란국','계란찜','고등어구이',
              '고등어조림','고사리나물','고추장진미채볶음','고추튀김','곰탕_설렁탕','곱창구이',
              '곱창전골','과메기','김밥','김치볶음밥','김치찌개','김치찜','깍두기','깻잎장아찌',
              '꼬막찜','꽁치조림','꽈리고추무침','꿀떡','나박김치','누룽지','닭갈비','닭계장','닭볶음탕',
              '더덕구이','도라지무침','도토리묵','동태찌개','된장찌개','두부김치','두부조림','땅콩조림',
              '떡갈비','떡국_만두국','떡꼬치','떡볶이','라면','라볶이','막국수','만두','매운탕','멍게',
              '메추리알장조림','멸치볶음','무국','무생채','물냉면','물회','미역국','미역줄기볶음','배추김치',
              '백김치','보쌈','부추김치','북엇국','불고기','비빔냉면','비빔밥','산낙지','삼겹살','삼계탕',
              '새우볶음밥','새우튀김','소세지볶음','송편','수육','수제비','숙주나물','순대','순두부찌개',
              '시금치나물','시래기국','알밥','애호박볶음','약과','약식','양념게장','양념치킨','어묵볶음',
              '연근조림','열무국수','열무김치','오이소박이','오징어채볶음','오징어튀김','우엉조림','유부초밥',
              '육개장','육회','잔치국수','잡곡밥','잡채','장어구이','장조림','전복죽','젓갈','제육볶음','조개구이',
              '조기구이','족발','주꾸미볶음','주먹밥','짜장면','짬뽕','쫄면','찜닭','총각김치','추어탕','칼국수',
              '코다리조림','콩국수','콩나물국','콩나물무침','콩자반','파김치','편육','피자','한과','해물찜','호박죽',
              '홍어무침','황태구이','회무침','후라이드치킨','훈제오리']  # os.listdir(dir) 
num_classes = len(categories)

image_w = 64
image_h = 64


for idx, cate in enumerate(categories):
    print(idx,cate)
    
    label = cate
    #one-hot 
    #label = [0 for i in range(num_classes)]
    #label[idx] = 1

    image_dir = dir + "\\" + cate
    files = glob.glob(image_dir+"\\*.jpg")
    print(cate, " 파일 길이 : ", len(files))
    for i, f in enumerate(files):

#         경로에 한글이 있다면 작동하지 않는다. 
#         직관성적인 한글 쓰기 위해 다른 방법 사용
#         img1 = cv2.imread(f,cv2.IMREAD_COLOR)
#         img = cv2.resize(img1, dsize=(64,64))

        img1 = Image.open(f)
        img2 = img1.convert("RGB")
        img3 = img2.resize((image_w, image_h))
        data = np.asarray(img)

        if i == 600 :
            print(cate, " : ", f)
            fig, ax = plt.subplots(1,2, figsize=(10,5))
            ax[0].imshow(img2)
            ax[0].set_title('Original Image')
            ax[1].imshow(img3)
            ax[1].set_title('Resized Image')
    break

#1시24분
# Out:
# 0 가지볶음
# 가지볶음  파일 길이 :  1000
# 가지볶음  :  D:\download\koreanfood\kfood\all\가지볶음\Img_040_0600.jpg

# %%
import os, re, glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
dir = 'D:\\download\\koreanfood\\kfood\\all'
categories = ['가지볶음','간장게장','갈비구이','갈비찜','갈비탕','갈치구이','갈치조림','감자조림',
              '감자채볶음','감자탕','갓김치','건새우볶음','경단','계란국','계란찜','고등어구이',
              '고등어조림','고사리나물','고추장진미채볶음','고추튀김','곰탕_설렁탕','곱창구이',
              '곱창전골','과메기','김밥','김치볶음밥','김치찌개','김치찜','깍두기','깻잎장아찌',
              '꼬막찜','꽁치조림','꽈리고추무침','꿀떡','나박김치','누룽지','닭갈비','닭계장','닭볶음탕',
              '더덕구이','도라지무침','도토리묵','동태찌개','된장찌개','두부김치','두부조림','땅콩조림',
              '떡갈비','떡국_만두국','떡꼬치','떡볶이','라면','라볶이','막국수','만두','매운탕','멍게',
              '메추리알장조림','멸치볶음','무국','무생채','물냉면','물회','미역국','미역줄기볶음','배추김치',
              '백김치','보쌈','부추김치','북엇국','불고기','비빔냉면','비빔밥','산낙지','삼겹살','삼계탕',
              '새우볶음밥','새우튀김','소세지볶음','송편','수육','수제비','숙주나물','순대','순두부찌개',
              '시금치나물','시래기국','알밥','애호박볶음','약과','약식','양념게장','양념치킨','어묵볶음',
              '연근조림','열무국수','열무김치','오이소박이','오징어채볶음','오징어튀김','우엉조림','유부초밥',
              '육개장','육회','잔치국수','잡곡밥','잡채','장어구이','장조림','전복죽','젓갈','제육볶음','조개구이',
              '조기구이','족발','주꾸미볶음','주먹밥','짜장면','짬뽕','쫄면','찜닭','총각김치','추어탕','칼국수',
              '코다리조림','콩국수','콩나물국','콩나물무침','콩자반','파김치','편육','피자','한과','해물찜','호박죽',
              '홍어무침','황태구이','회무침','후라이드치킨','훈제오리']  # os.listdir(dir) 
num_classes = len(categories)

image_w = 64
image_h = 64

pixels = image_h * image_w * 3

X = []
y = []

for idx, cate in enumerate(categories):
    print(idx,cate)
    
    label = cate
    #one-hot 
    #label = [0 for i in range(num_classes)]
    #label[idx] = 1

    image_dir = dir + "\\" + cate
    files = glob.glob(image_dir+"\\*.jpg")
    print(cate, " 파일 길이 : ", len(files))
    for i, f in enumerate(files):

#         경로에 한글이 있다면 작동하지 않는다. 
#         직관성적인 한글 쓰기 위해 다른 방법 사용
#         img1 = cv2.imread(f,cv2.IMREAD_COLOR)
#         img = cv2.resize(img1, dsize=(64,64))

        img = Image.open(f)
        img = img.convert("RGB")
        img = img.resize((image_w, image_h))
        data = np.asarray(img)

        X.append(data)
        y.append(label)

        if i == 600 :
            print(cate, " : ", f)
#             fig, ax = plt.subplots(1,2, figsize=(10,5))
#             ax[0].imshow(img1)
#             ax[0].set_title('Original Image')
#             ax[1].imshow(img2)
#             ax[1].set_title('Resized Image')

X = np.array(X)
y = np.array(y)

#30분정도 소요
#1시24분
# Out:
# 0 가지볶음
# 가지볶음  파일 길이 :  1000
# 가지볶음  :  D:\download\koreanfood\kfood\all\가지볶음\Img_040_0600.jpg
# 1 간장게장
# 간장게장  파일 길이 :  999
# 간장게장  :  D:\download\koreanfood\kfood\all\간장게장\Img_093_0602.jpg
# 2 갈비구이
# 갈비구이  파일 길이 :  998
# 갈비구이  :  D:\download\koreanfood\kfood\all\갈비구이\Img_000_0601.jpg
# 3 갈비찜
# 갈비찜  파일 길이 :  991
# 갈비찜  :  D:\download\koreanfood\kfood\all\갈비찜\Img_124_0609.jpg
# 4 갈비탕
# 갈비탕  파일 길이 :  1000
# 갈비탕  :  D:\download\koreanfood\kfood\all\갈비탕\Img_134_0600.jpg
# 5 갈치구이
# 갈치구이  파일 길이 :  998
# 갈치구이  :  D:\download\koreanfood\kfood\all\갈치구이\Img_001_0601.jpg
# 6 갈치조림
# 갈치조림  파일 길이 :  1004
# 갈치조림  :  D:\download\koreanfood\kfood\all\갈치조림\Img_106_0601.jpg
# 7 감자조림
# 감자조림  파일 길이 :  1000
# 감자조림  :  D:\download\koreanfood\kfood\all\감자조림\Img_107_0601.jpg
# 8 감자채볶음
# 감자채볶음  파일 길이 :  1000
# 감자채볶음  :  D:\download\koreanfood\kfood\all\감자채볶음\Img_078_0600.jpg
# 9 감자탕
# 감자탕  파일 길이 :  997
# 감자탕  :  D:\download\koreanfood\kfood\all\감자탕\Img_135_0605.jpg
# 10 갓김치
# 갓김치  파일 길이 :  990
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)
xy = (X_train, X_test, y_train, y_test)
np.save(".\\multi_image_data_1.npy", xy)
# Out:
# C:\Users\hyeon\AppData\Roaming\Python\Python38\site-packages\numpy\lib\npyio.py:501: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)

# %%
X_train[101]
# Out:
# array([[[231, 233, 230],
#         [231, 233, 230],
#         [232, 234, 231],
#         ...,
#         [238, 239, 235],
#         [238, 239, 234],
#         [238, 239, 234]],
#
#        [[231, 233, 230],
#         [231, 233, 230],
#         [231, 233, 230],
#         ...,
#         [238, 239, 235],
#         [238, 239, 234],
#         [238, 239, 234]],
#
#        [[230, 232, 229],
#         [231, 233, 230],
#         [231, 233, 230],
#         ...,
#         [238, 239, 235],
#         [238, 239, 235],
#         [238, 239, 235]],
#
#        ...,
#
#        [[242, 238, 238],
#         [241, 237, 238],
#         [239, 234, 236],
#         ...,
#         [238, 230, 228],
#         [237, 230, 227],
#         [237, 230, 228]],
#
#        [[241, 237, 236],
#         [242, 238, 237],
#         [240, 236, 234],
#         ...,
#         [238, 230, 228],
#         [239, 231, 229],
#         [239, 232, 230]],
#
#        [[241, 236, 233],
#         [242, 237, 234],
#         [238, 233, 230],
# ...

# %%
y_train[101]
# Out:
# '감자조림'

# %%
X_train, X_test, y_train, y_test = np.load('./multi_image_data_1.npy')
print(X_train.shape)
print(X_train.shape[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 X_train, X_test, y_train, y_test = np.load('./multi_image_data_1.npy')
#       2 print(X_train.shape)
#       3 print(X_train.shape[0])
#
# File ~\AppData\Roaming\Python\Python38\site-packages\numpy\lib\npyio.py:413, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     411         return format.open_memmap(file, mode=mmap_mode)
#     412     else:
# --> 413         return format.read_array(fid, allow_pickle=allow_pickle,
#     414                                  pickle_kwargs=pickle_kwargs)
#     415 else:
#     416     # Try a pickle
#     417     if not allow_pickle:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\numpy\lib\format.py:741, in read_array(fp, allow_pickle, pickle_kwargs)
#     738 if dtype.hasobject:
# ...

# %%
X_train = X_train / 255 # .astype(float)

# %%
X_test = X_test / 255  # .astype(float)

# %%
X_train[101]
# Out:
# array([[[0.90588235, 0.91372549, 0.90196078],
#         [0.90588235, 0.91372549, 0.90196078],
#         [0.90980392, 0.91764706, 0.90588235],
#         ...,
#         [0.93333333, 0.9372549 , 0.92156863],
#         [0.93333333, 0.9372549 , 0.91764706],
#         [0.93333333, 0.9372549 , 0.91764706]],
#
#        [[0.90588235, 0.91372549, 0.90196078],
#         [0.90588235, 0.91372549, 0.90196078],
#         [0.90588235, 0.91372549, 0.90196078],
#         ...,
#         [0.93333333, 0.9372549 , 0.92156863],
#         [0.93333333, 0.9372549 , 0.91764706],
#         [0.93333333, 0.9372549 , 0.91764706]],
#
#        [[0.90196078, 0.90980392, 0.89803922],
#         [0.90588235, 0.91372549, 0.90196078],
#         [0.90588235, 0.91372549, 0.90196078],
#         ...,
#         [0.93333333, 0.9372549 , 0.92156863],
#         [0.93333333, 0.9372549 , 0.92156863],
#         [0.93333333, 0.9372549 , 0.92156863]],
#
#        ...,
#
#        [[0.94901961, 0.93333333, 0.93333333],
# ...
